# %%
# Import dependencies
import pandas as pd
import requests
import numpy as np

# %%
# Read data from csv
filepath = 'all_time_traffic_incidents_20240119.csv'
df = pd.read_csv(filepath)

# %%
# Check df
df.head()
# Out:
#                                    Traffic Report ID       Published Date  \
# 0  C163BCD1CF90C984E9EDA4DBA311BCA369A7D1A1_15288...  2018-06-13 06:35:59
# 1  6B20382196FB454E9FD06A33E60142902A2F0706_15288...  2018-06-13 10:15:36
# 2  2A7A84FC69D56A2C379C274D2F0831442D3E7B8E_15871...  2020-04-17 21:25:03
# 3  89D3B75BB5932F10D25B5852A9902DA26C3DF11A_15871...  2020-04-17 21:40:52
# 4  E7F9EFF0E81057A5C8FE41CABE4D9C6EEA82DAA0_15871...  2020-04-17 21:00:55
#
#    Issue Reported                Location   Latitude  Longitude  \
# 0   Crash Service  (30.283797,-97.741906)  30.283797 -97.741906
# 1  Traffic Hazard  (30.339593,-97.700963)  30.339593 -97.700963
# 2    Crash Urgent  (30.329455,-97.638105)  30.329455 -97.638105
# 3  Traffic Hazard  (30.202806,-97.760701)  30.202806 -97.760701
# 4    Crash Urgent  (30.184265,-97.687339)  30.184265 -97.687339
#
#                                        Address    Status          Status Date
# 0                     W 21ST ST & GUADALUPE ST  ARCHIVED  2018-06-13 09:00:03
# 1                     400-717 E ANDERSON LN EB  ARCHIVED  2018-06-13 11:20:03
# 2  E US 290 HWY SVRD EB & EASTERN HEIGHTS BLVD  ARCHIVED  2020-04-17 21:55:03
# 3                          5300-blk S Ih 35 Sb  ARCHIVED  2020-04-17 21:55:03
# 4                    4500-4720 S Us 183 Hwy Sb  ARCHIVED  2020-04-17 23:30:04

# %%
# Combine all crash and collision incident types
df.loc[df['Issue Reported'].isin(['Crash Urgent',
                                'Crash Service',
                                'Collision',
                                'Collision With Injury',
                                'Collision/Leaving Scene',
                                'Collision/Private Property']),'Issue Reported'] = 'Collision/Crash'

# Extract only crashes & collisions
df_c = df.loc[df['Issue Reported']=='Collision/Crash'].drop(columns=['Issue Reported','Location', 'Status', 'Status Date',
                                                                     'Address','Traffic Report ID'])

# %%
df_c.head()
# Out:
#          Published Date   Latitude  Longitude
# 0   2018-06-13 06:35:59  30.283797 -97.741906
# 2   2020-04-17 21:25:03  30.329455 -97.638105
# 4   2020-04-17 21:00:55  30.184265 -97.687339
# 5   2020-04-17 21:44:39  30.353742 -97.690482
# 12  2020-04-19 00:12:08  30.333755 -97.470972
